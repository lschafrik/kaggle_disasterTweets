# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/train.csv')

# %%
df
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# ...

# %%
# replace keyword %20 with space or split 
# split text to find if any words within keyword list
    # if in keyword list, and keyword cell is NaN, fill keyword with that word
    
# if necessary, use country and state lists to do the same to fill in location values

# split and clean text

# clean out http/www and hashtags.. and emojis?

df[df['keyword'].isnull()]
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# ...

# %%
keyword_list = df['keyword'].unique()

# %%
.fillna()

# %%
us_states = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]

# %%
from country_list import countries_for_language

# %%
countries = dict(countries_for_language('en'))

# %%
countries
# Out:
# {'AF': 'Afghanistan',
#  'AX': 'Åland Islands',
#  'AL': 'Albania',
#  'DZ': 'Algeria',
#  'AS': 'American Samoa',
#  'AD': 'Andorra',
#  'AO': 'Angola',
#  'AI': 'Anguilla',
#  'AQ': 'Antarctica',
#  'AG': 'Antigua & Barbuda',
#  'AR': 'Argentina',
#  'AM': 'Armenia',
#  'AW': 'Aruba',
#  'AU': 'Australia',
#  'AT': 'Austria',
#  'AZ': 'Azerbaijan',
#  'BS': 'Bahamas',
#  'BH': 'Bahrain',
#  'BD': 'Bangladesh',
#  'BB': 'Barbados',
#  'BY': 'Belarus',
#  'BE': 'Belgium',
#  'BZ': 'Belize',
#  'BJ': 'Benin',
#  'BM': 'Bermuda',
#  'BT': 'Bhutan',
#  'BO': 'Bolivia',
#  'BA': 'Bosnia & Herzegovina',
#  'BW': 'Botswana',
#  'BV': 'Bouvet Island',
#  'BR': 'Brazil',
#  'IO': 'British Indian Ocean Territory',
#  'VG': 'British Virgin Islands',
#  'BN': 'Brunei',
#  'BG': 'Bulgaria',
#  'BF': 'Burkina Faso',
#  'BI': 'Burundi',
#  'KH': 'Cambodia',
#  'CM': 'Cameroon',
#  'CA': 'Canada',
#  'CV': 'Cape Verde',
#  'BQ': 'Caribbean Netherlands',
#  'KY': 'Cayman Islands',
# ...

# %%
from spellchecker import SpellChecker

# %%
spell = SpellChecker()

# %%
spell.correction('corect')
# Out:
# 'correct'

# %%
import unicodedata
import string
import re
from nltk.util import ngrams
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import  SnowballStemmer

# %%
sw = stopwords.words('english')
pt = string.punctuation
stemmer = SnowballStemmer('english')

# %%
for tweet in df['text']:
    print(tweet.lower())
    break
# Out:
# our deeds are the reason of this #earthquake may allah forgive us all

# %%
doc = word_tokenize(df['text'][7610].lower())
doc = [token for token in doc if token not in sw and token not in pt]
# doc = [stemmer.stem(token) for token in doc] # don't use, it takes the 'e' off 'earthquake'

# %%
doc
# Out:
# ['m1.94',
#  '01:04',
#  'utc',
#  '5km',
#  'volcano',
#  'hawaii',
#  'http',
#  '//t.co/zdtoyd8ebj']

# %%
extra_stopwords =

# %%
# print('Canada' in countries.values())
# Out:
# True

# %%
for word in doc:
    print(spell.correction(word))
# Out:
# aha
# south
# tampa
# getting
# flooded
# hah
# wait
# second
# live
# south
# tampa
# gon
# na
# gon
# na
# fuck
# flooding
